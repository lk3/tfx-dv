# %% [markdown]
# # Patent data

# %%
import scipat

conn = scipat.WebConnection(use_selenium=False, user_agent='Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36')

res = scipat.Search('microsoft', results_limit=10, web_connection=conn)

print(res)
# Out:
#                                                      abstract applicant_city  \
# patent_num
# RE47,678    A system and method for managing a permit-base...     Somerville
# RE47,676    A user interface of a smart compact device emp...       San Jose
# D864,767                                                 None  San Francisco
# 10,462,838  A computer implemented method of controlling a...       Purchase
# 10,462,788  A method and apparatus operate a device on a l...        Chicago
# 10,462,239  A machine may be configured to perform A/B tes...        Redmond
# 10,462,238  A reachability engine can determine a reachabi...      Sunnyvale
# 10,462,235  Described herein is technology for, among othe...        Redmond
# 10,462,231  The present teaching relates to continuing a u...       New York
# 10,462,228  Access to a redirected smart card can be provi...    Santa Clara
#
#            applicant_country                         applicant_name  \
# patent_num
# ...
